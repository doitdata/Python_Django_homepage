# %%
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f503e9c6cf11> in <module>
# ----> 1 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
# !python --version
# Out:
# Python 3.6.10 :: Anaconda, Inc.

# %%
# !conda list
# Out:
# # packages in environment at D:\anaconda\envs\chch4934:
# #
# # Name                    Version                   Build  Channel
# _r-mutex                  1.0.0               anacondar_1
# _tflow_select             2.2.0                     eigen
# absl-py                   0.9.0                    py36_0
# alabaster                 0.7.12                   py36_0
# apriori                   1.0.0                    pypi_0    pypi
# apyori                    1.1.2                    pypi_0    pypi
# argh                      0.26.2                   py36_0
# asn1crypto                1.3.0                    py36_0
# astor                     0.8.1                    pypi_0    pypi
# astroid                   2.3.3                    py36_0
# atomicwrites              1.3.0                    py36_1
# attrs                     19.3.0                     py_0
# automat                   20.2.0                   pypi_0    pypi
# ...
