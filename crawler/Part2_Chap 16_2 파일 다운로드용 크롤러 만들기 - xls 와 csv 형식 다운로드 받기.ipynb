# %%
# 필요한 모듈과 라이브러리를 로딩 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import os

# %%
print('=' * 100)
print('예제 파일 다운로드용 크롤러 만들기 - xls와 csv 형식 다운로드')
print('=' *100)

# 사용자에게 주소 입력을 받습니다. 
url_addr = input('1. 파일 다운로드할 웹 페이지 주소를 입력하세요: ')

f_dir = input('2. 파일이 저장될 경로만 쓰세요: ')

if os.path.isdir(f_dir):
    print('입력하신 경로가 존재하여 %s 폴더에 저장하겠습니다.' %f_dir)
else:
    os.makedirs(f_dir)
    print('입력하신 경로가 존재하지 않아 %s 폴더를 생성합니다. ' %f_dir)
    
choice = input('''
1. 전체
2. KOSPI
3. KOSDAQ
위 번호 중 조회할 시장 번호를 선택하세요.:  ''')

f_choice = input('''
1. xls 형식으로 저장하기.
2. csv 형식으로 저장하기
위 번호 중 저장할 파일 형식의 번호를 선택하세요:  ''')

print('\n')
print('요청하신 데이터를 수집 중이오니 기다리세요.')

# 크롬드라이버를 사용해서 웹 브라우저를 실행합니다. 
s_time = time.time( )

options = webdriver.ChromeOptions()

path = './chromedriver.exe'
driver = webdriver.Chrome(path, options=options)

prefs = {'download.default_directory' : f_dir}
options.add_experimental_option('prefs', prefs)

# options.add_experimental_option("prefs", {
#       "download.default_directory": f_dir,
#       "download.prompt_for_download": False,
#       "plugins.always_open_pdf_externally": True,
#       "safebrowsing.enabled": True
# })

driver.command_executor._commands["send_command"] = ("POST", '/session/$sessionId/chromium/send_command')
params = {'cmd': 'Page.setDownloadBehavior', 'params': {'behavior': 'allow', 'downloadPath': f_dir}}
command_result = driver.execute("send_command", params)

driver.get(url_addr)

# time.sleep(random.randrange(2,5))

time.sleep(10)

# 전체 / KOSPI / KOSDAQ 라디오 버튼 선택 후 조회 버튼 누르기

if choice =='1':
    radio = driver.find_element_by_id('gubuna87ff679a2f3e71d9181a67b7542122c')
    radio.click()
    driver.find_element_by_id('btnidc81e728d9d4c2f636f067f89cc14862c').click()
elif choice =='2':
    radio = driver.find_element_by_id('gubun1a87ff679a2f3e71d9181a67b7542122c')
    radio.click()
    driver.find_element_by_id('btnidc81e728d9d4c2f636f067f89cc14862c').click()
elif choice =='3':
    radio =  driver.find_element_by_id('gubun2a87ff679a2f3e71d9181a67b7542122c')
    radio.click()
    driver.find_element_by_id('btnidc81e728d9d4c2f636f067f89cc14862c').click()
else:
    print('번호를 다시 확인해 주세요.')
    
time.sleep(10)    
    
# xls 형태와 csv 형태의 파일로 다운로드 받기
if f_choice =='1':
    driver.find_element_by_xpath("""//*[@id="e4da3b7fbbce2345d7772b0674a318d5"]/button[3]""").click()
elif f_choice =='2':
    driver.find_element_by_xpath("""//*[@id="e4da3b7fbbce2345d7772b0674a318d5"]/button[4]""").click()
    
time.sleep(10)

e_time = time.time()
t_time = e_time - s_time

# 요약 정보 보여주기
print('=' * 100)
print('총 소요시간은 %s 초 입니다.' %round(t_time,1))
print('파일이 저장된 폴더명: %s' %f_dir)
print('=' * 100)

# driver.close()
# Out:
# ====================================================================================================
# 예제 파일 다운로드용 크롤러 만들기 - xls와 csv 형식 다운로드
# ====================================================================================================
# 1. 파일 다운로드할 웹 페이지 주소를 입력하세요: http://marketdata.krx.co.kr/mdi#document=040301
# 2. 파일이 저장될 경로만 쓰세요: D:\\Python_Project\\portfolio\\study_coding\\book\\완친파 웹크롤러대마왕/
# 입력하신 경로가 존재하여 D:\\Python_Project\\portfolio\\study_coding\\book\\완친파 웹크롤러대마왕/ 폴더에 저장하겠습니다.
#
# 1. 전체
# 2. KOSPI
# 3. KOSDAQ
# 위 번호 중 조회할 시장 번호를 선택하세요.:  1
#
# 1. xls 형식으로 저장하기.
# 2. csv 형식으로 저장하기
# 위 번호 중 저장할 파일 형식의 번호를 선택하세요:  1
#
#
# 요청하신 데이터를 수집 중이오니 기다리세요.
# ====================================================================================================
# 총 소요시간은 44.9 초 입니다.
# 파일이 저장된 폴더명: D:\\Python_Project\\portfolio\\study_coding\\book\\완친파 웹크롤러대마왕/
# ====================================================================================================

# %%
# http://marketdata.krx.co.kr/mdi#document=040301
# D:/Python_Project/portfolio/study_coding/book/완친파 웹크롤러대마왕/
# D:\\Python_Project\\portfolio\\study_coding\\book\\완친파 웹크롤러대마왕/
