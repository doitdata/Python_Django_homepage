# %% [markdown]
# ### 함수의 기본

# %% [markdown]
# def 함수 이름():
#     코드

# %%
def print_3_times():
    print("안녕하세요")
    print("안녕하세요")
    print("안녕하세요")

print_3_times()

# 안녕하세요
# 안녕하세요
# 안녕하세요
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# ### 함수에 매개변수 만들기

# %% [markdown]
# def 함수이름 (매개변수):
#     코드

# %% [markdown]
# 함수를 호출할 때 매개변수를 넣지 않거나 더 많이 넣으면 에러가 발생

# %%
def print_n_times(value, n):
    for i in range(n):
        print(value)
        
print_n_times("안녕하세요", 5)

# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# 가변매개변수
# : 매개변수를 원하는 만큼 받을 수 있는 함수

# %% [markdown]
# def 함수이름 (매개변수, 매개변수, ....*매개변수):
#     코드

# %%
def print_n_times(n, *values):
    # n번 반복합니다.
    for i in range(n):
        # values는 리스트처럼 활용합니다.
        for value in values:
            print(value)
        # 단순한 줄바꿈
        print()

# 함수를 호출합니다.
print_n_times(3, "안녕하세요", "즐거운", "파이썬 프로그래밍")

# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %% [markdown]
# 기본매개 변수
# "매개변수 = 값" 형태로 되어 있음
# 기본 매개 변수 뒤에는 일반 매개변수가 올 수 없음

# %%
def print_n_times(value, n=2):  # n=2 가 기본 매개 변수
    # n번 반복합니다.
    for i in range(n):
        print(value)

# 함수를 호출합니다.
print_n_times("안녕하세요")

# 안녕하세요
# 안녕하세요
# Out:
# 안녕하세요
# 안녕하세요

# %% [markdown]
# 키워드 매개변수
# - 기본매개변수가 가변매개변수보다 앞에 올때는 에러가 발생

# %%
def print_n_times(n=2, *value):  # n=2 가 기본 매개 변수
    # n번 반복합니다.
    for i in range(n):
        print(value)

# 함수를 호출합니다.
print_n_times("안녕하세요")

# 에러 'str' object cannot be interpreted as an integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-181bf90f204c> in <module>
#       5
#       6 # 함수를 호출합니다.
# ----> 7 print_n_times("안녕하세요")
#       8
#       9 # 에러
#
# <ipython-input-13-181bf90f204c> in print_n_times(n, *value)
#       1 def print_n_times(n=2, *value):  # n=2 가 기본 매개 변수
#       2     # n번 반복합니다.
# ----> 3     for i in range(n):
#       4         print(value)
#       5
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# - 가변매개변수가 기본매개변수보다 앞에 올때, 가변 매개변수가 우선

# %%
def print_n_times(*value, n=2):  # n=2 가 기본 매개 변수
    # n번 반복합니다.
    for i in range(n):
        print(value)

# 함수를 호출합니다.
print_n_times("안녕하세요",'즐거운','파이썬 프로그래밍',3)

# 두가지 예측이 가능
# ['안녕하세요', '즐거운', '파이썬 프로그래밍'] 이 3번 출력
# ['안녕하세요', '즐거운', '파이썬 프로그래밍', 3]이 2번 출력
# 가변 매개변수가 우선이므로 후자인 두번째 코드로 결론이 나옴
# Out:
# ('안녕하세요', '즐거운', '파이썬 프로그래밍', 3)
# ('안녕하세요', '즐거운', '파이썬 프로그래밍', 3)

# %% [markdown]
# 기본 매개변수와 가변 매개변수를 함께 사용할 수 있는 방법 => 키워드 매개변수

# %%
def print_n_times(*values, n=2):
    # n번 반복합니다.
    for i in range(n):
        # values는 리스트처럼 활용합니다.
        for value in values:
            print(value)
        # 단순한 줄바꿈
        print()

# 함수를 호출합니다.
print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍", n=3) # 호출할 때 매개변수 이름을 지정해서 입력하는 키워드 매개변수 n=3 사용

# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %% [markdown]
# 기본 매개변수 중에서 필요한 값만 입력하기
# 일반적으로 일바 매개변수는 필수로 입력을 하고, 순서에 맞게 입력을 하면 됨
# 기본 매개변수는 필요한 것만 키워드로 지정해서 입력하는 경우가 많음

# %%
def test(a, b=10, c=100):
    print(a + b + c)

# 1) 기본 형태
test(10, 20, 30) # 60

# 2) 키워드 매개변수로 모든 매개변수를 지정한 형태
test(a=10, b=100, c=200) # 310

# 3) 키워드 매개변수로 모든 매개변수를 마구잡이로 지정한 형태
test(c=10, a=100, b=200) # 310

# 4) 키워드 매개변수로 일부 매개변수만 지정한 형태
test(10, c=200) # 220
# Out:
# 60
# 310
# 310
# 220

# %% [markdown]
# #### return
# 1) 함수를 실행했던 위치로 돌아가라는 의미
# 2) 함수를 여기서 끝내다의 의미

# %% [markdown]
# 자료 없이 리턴하기

# %%
# 함수를 정의합니다.
def return_test():
    print("A 위치입니다.")
    return # 리턴합니다.
    print("B 위치입니다.")

# 함수를 호출합니다.
return_test() # A 위치입니다.
# Out:
# A 위치입니다.

# %% [markdown]
# 자료와 함꼐 리턴하기

# %%
# 함수를 정의합니다.
def return_test():
    return 100

# 함수를 호출합니다.
value = return_test()
print(value) # 100
# Out:
# 100

# %% [markdown]
# 아무것도 리턴하지 않기

# %%
# 함수를 정의합니다.
def return_test():
    return

# 함수를 호출합니다.
value = return_test()
print(value) # None
# Out:
# None

# %% [markdown]
# 기본적인 함수의 활용

# %% [markdown]
# def 함수(매개변수):
#     변수 = 초기값
#     # 여러가지 처리하는 코드 1
#     # 여러가지 처리하는 코드 2
#     # 여러가지 처리하는 코드 3
#     return 변수

# %%
# 함수를 선언합니다.
def sum_all(start, end):
    # 변수를 선언합니다.
    output = 0
    # 반복문을 돌려 숫자를 더합니다.
    for i in range(start, end + 1):
        output += i
    # 리턴합니다.
    return output

# 함수를 호출합니다.
print("0 to 100:", sum_all(0, 100)) # 0 to 100: 5050
print("0 to 1000:", sum_all(0, 1000)) # 0 to 1000: 500500
print("50 to 100:", sum_all(50, 100)) # 50 to 100: 3825
print("500 to 1000:", sum_all(500, 1000)) # 500 to 1000: 375750
# Out:
# 0 to 100: 5050
# 0 to 1000: 500500
# 50 to 100: 3825
# 500 to 1000: 375750

# %%
# 함수를 선언합니다.
def sum_all(start=0, end=100, step=1):
    # 변수를 선언합니다.
    output = 0
    # 반복문을 돌려 숫자를 더합니다.
    for i in range(start, end + 1, step):
        output += i
    # 리턴합니다.
    return output

# 함수를 호출합니다.
print("A.", sum_all(0, 100, 10)) # 550
print("B.", sum_all(end=100)) # 5050
print("C.", sum_all(end=100, step=2)) # 2550
# Out:
# A. 550
# B. 5050
# C. 2550

# %% [markdown]
# 재귀함수 :자기자신을 호출하는 것
# - 팩토리얼을 구하는 방법
# 1) 반복문으로 팩토리얼을 구한다
# 2) 재귀 함수로 팩토리얼을 구한다

# %%
# 1) 반복문으로 팩토리얼을 구한다
# 함수를 선언합니다.
def factorial(n):
    # 변수를 선언합니다.
    output = 1
    # 반복문을 돌려 숫자를 더합니다.
    for i in range(1, n + 1):
        output *= i
    # 리턴합니다.
    return output

# 함수를 호출합니다.
print("1!:", factorial(1)) # 1!: 1
print("2!:", factorial(2)) # 2!: 2
print("3!:", factorial(3)) # 3!: 6
print("4!:", factorial(4)) # 4!: 24
print("5!:", factorial(5)) # 5!: 120
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120

# %%
# 2) 재귀 함수로 팩토리얼을 구한다
# 함수를 선언합니다.
def factorial(n):
    # n이 0이라면 1을 리턴
    if n == 0:
        return 1
    # n이 0이 아니라면 n * (n-1)!을 리턴
    else:
        return n * factorial(n - 1)

# 함수를 호출합니다.
print("1!:", factorial(1)) # 1!: 1
print("2!:", factorial(2)) # 2!: 2
print("3!:", factorial(3)) # 3!: 6
print("4!:", factorial(4)) # 4!: 24
print("5!:", factorial(5)) # 5!: 120
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120

# %% [markdown]
# 재귀 함수의 문제
# 상황에 따라서 같은 것을 기하급수적으로 많이 반복한다는 문제가 있음
# 해결방법은 메모리화 기술로 가능!

# %%
# 함수를 선언합니다.
def fibonacci(n):
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# 함수를 호출합니다.
print("fibonacci(1):", fibonacci(1)) # fibonacci(1): 1
print("fibonacci(2):", fibonacci(2)) # fibonacci(2): 1
print("fibonacci(3):", fibonacci(3)) # fibonacci(3): 2
print("fibonacci(4):", fibonacci(4)) # fibonacci(4): 3
print("fibonacci(5):", fibonacci(5)) # fibonacci(5): 5
# Out:
# fibonacci(1): 1
# fibonacci(2): 1
# fibonacci(3): 2
# fibonacci(4): 3
# fibonacci(5): 5

# %%
# 변수를 선언합니다.
counter = 0

# 함수를 선언합니다.
def fibonacci(n):
    # 어떤 피보나치 수를 구하는지 출력합니다.
    print("fibonacci({})를 구합니다.".format(n))
    global counter
    counter += 1
    # 피보나치 수를 구합니다.
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# 함수를 호출합니다.
fibonacci(10)
print("---")
print("fibonacci(10) 계산에 활용된 덧셈 횟수는 {}번입니다.".format(counter))

# 현재 코드의 재귀 함수는 한번 구했던 값이라도 처음부터 다시 계산해야 합니다. 그래서 계산 횟수가 기하급수적으로 늘어나는 것
# Out:
# fibonacci(10)를 구합니다.
# fibonacci(9)를 구합니다.
# fibonacci(8)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# ...

# %% [markdown]
# UnboundLocalError 에러에 대한 처리
# - 함수 내부에서 함수 외부에 있는 변수인 count를 참조하지 못함. 그래서 에러발생
# - 이 경우 global 변수이름을 써서 전역변수로 만들어 준다.

# %%
# 변수를 선언합니다.
counter = 0

# 함수를 선언합니다.
def fibonacci(n):
    counter += 1
    # 피보나치 수를 구합니다.
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

# 함수를 호출합니다.
print(fibonacci(10)) # UnboundLocalError 에러 발생
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-28-06e7741161de> in <module>
#      14
#      15 # 함수를 호출합니다.
# ---> 16 print(fibonacci(10))
#
# <ipython-input-28-06e7741161de> in fibonacci(n)
#       4 # 함수를 선언합니다.
#       5 def fibonacci(n):
# ----> 6     counter += 1
#       7     # 피보나치 수를 구합니다.
#       8     if n == 1:
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %% [markdown]
# 메모화
# : 딕셔너리를 사용해서 한 번 계산한 값을저장
# : 딕셔너리에 값이 메모되어 있으면 처리를 수행하지 않고 곧바로 메모된 값을 돌려주면서 코드의 속도롤 빠르게 만드는 것

# %%
# 메모 변수를 만듭니다.
dictionary = {
    1: 1,
    2: 2
}

# 함수를 선언합니다.
def fibonacci(n):
    if n in dictionary:
        # 메모 되어 있으면 메모된 값 리턴
        return dictionary[n]
    else:
        # 메모 되어 있지 않으면 값을 구함
        output = fibonacci(n - 1) + fibonacci(n - 2)
        dictionary[n] = output
        return output

# 함수를 호출합니다.
print("fibonacci(10):", fibonacci(10)) # fibonacci(10): 89
print("fibonacci(20):", fibonacci(20)) # fibonacci(20): 10946
print("fibonacci(30):", fibonacci(30)) # fibonacci(30): 1346269
print("fibonacci(40):", fibonacci(40)) # fibonacci(40): 165580141
print("fibonacci(50):", fibonacci(50)) # fibonacci(50): 20365011074
# Out:
# fibonacci(10): 89
# fibonacci(20): 10946
# fibonacci(30): 1346269
# fibonacci(40): 165580141
# fibonacci(50): 20365011074

# %% [markdown]
# 조기리턴
# 중간에 return 키워드를 사용하기

# %% [markdown]
# 튜플
# : 함수와 함꼐 많이 사용되는 리스트와 비슷한 자료형으로, 리스트와 다른 점은 한번 결정된 요소는 바꿀 수 없음
# : (데이터, 데이터, 데이터...)
# : 요소를 하나만 가지는 튜플의 표현은 (273, )

# %% [markdown]
# - 괄호없는 튜플

# %%
# 리스트와 튜플의 특이한 사용
[a, b] = [10, 20]
(c, d) = (10, 20)

# 출력합니다.
print("a:", a) # a: 10
print("b:", b) # b: 20
print("c:", c) # c: 10
print("d:", d) # d: 20
# Out:
# a: 10
# b: 20
# c: 10
# d: 20

# %%
# 괄호가 없는 튜플
tuple_test = 10, 20, 30, 40
print("tuple_test:", tuple_test) # tuple_test: (10, 20, 30, 40)
print("type(tuple_test):", type(tuple_test))
print()

# 괄호가 없는 튜플 활용
a, b, c = 10, 20, 30
print("a:", a) # a: 10
print("b:", b) # b: 20
print("c:", c) # c: 30
# Out:
# # 괄호가 없는 튜플의 값과 자료형 출력
# tuple_test: (10, 20, 30, 40)
# type(tuple_test): <class 'tuple'>
#
# # 괄호가 없는 튜플을 활용한 할당
# a: 10
# b: 20
# c: 30

# %% [markdown]
# - 변수의 값을 교환하는 튜플

# %%
a, b = 10, 20

print("# 교환 전 값")
print("a:", a)
print("b:", b)
print()

# 값을 교환합니다.
a, b = b, a

print("# 교환 후 값")
print("a:", a)
print("b:", b)
print()
# Out:
# # 교환 전 값
# a: 10
# b: 20
#
# # 교환 후 값
# a: 20
# b: 10

# %% [markdown]
# - 여러개의 값 리턴하기

# %%
# 함수를 선언합니다.
def test():
    return (10, 20)

# 여러 개의 값을 리턴받습니다.
a, b = test()

# 출력합니다.
print("a:", a)
print("b:", b)
# Out:
# a: 10
# b: 20

# %% [markdown]
# 람다
# : 매개변수로 함수를 전달하기 위해 함수구분을 작성하는 것이 번거롭고, 코드 공간 낭비라는 생각이 들때 함수를 간단하고 쉽게 선언하는 방법

# %% [markdown]
# - 함수의 매개변수로 함수 전달하기

# %%
# 매개변수로 받은 함수를 10번 호출하는 함수
def call_10_times(func):
    for i in range(10):
        func()

# 간단한 출력하는 함수
def print_hello():
    print("안녕하세요")

# 조합하기
call_10_times(print_hello)
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# - 함수를 매개변수로 전달하는 대표적인 표준 함수로 map() 함수와 filter() 함수가 있음

# %% [markdown]
# map() 함수는 리스트의 요소를 함수에 넣고 리턴값으로 새로운 리스트를 구성해 주는 함수
# map(함수, 리스트)

# %% [markdown]
# filter() 함수는 리스트의 요소를 함수에 넣고 리턴된 값이 True인 것으로, 새로운 리스트를 구성해주는 함수
# filter(함수, 리스트)

# %%
# 함수를 선언합니다.
def power(item):
    return item * item
def under_3(item):
    return item < 3

# 변수를 선언합니다.
list_input_a = [1, 2, 3, 4, 5]

# map() 함수를 사용합니다.
output_a = map(power, list_input_a)
print("map(power, list_input_a):", output_a) # map(power, list_input_a): <map object at 0x00000243CBD83240>
print("map(power, list_input_a):", list(output_a)) # map(power, list_input_a): [1, 4, 9, 16, 25]
print()

# filter() 함수를 사용합니다.
output_b = filter(under_3, list_input_a)
print("filter(under_3, list_input_a):", output_b)  # filter(under_3, list_input_a): <filter object at 0x00000243CBD83358>
print("filter(under_3, list_input_a):", list(output_b)) # filter(under_3, list_input_a): [1, 2]

# map object, filter object는 제너레이터로, list함수를 적용해 강제로 리스트 자료형으로 변형해 출력
# 제너레이터 객체는 next() 함수를 사용해 함수 내부의 코드를 실행
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a): <map object at 0x00000243CBD83240>
# map(power, list_input_a): [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a): <filter object at 0x00000243CBD83358>
# filter(under_3, list_input_a): [1, 2]

# %% [markdown]
# 람다의 개념
# 간단한 함수를 선언하는 방법
# lambda 매개변수 :리턴값

# %%
# 함수를 선언합니다.
power = lambda x: x * x
under_3 = lambda x: x < 3

# 변수를 선언합니다.
list_input_a = [1, 2, 3, 4, 5]

# map() 함수를 사용합니다.
output_a = map(power, list_input_a)
print("map(power, list_input_a):", output_a) # map(power, list_input_a): <map object at 0x00000243CBD83438>
print("map(power, list_input_a):", list(output_a)) # map(power, list_input_a): [1, 4, 9, 16, 25]
print()

# filter() 함수를 사용합니다.
output_b = filter(under_3, list_input_a)
print("filter(under_3, list_input_a):", output_b) # filter(under_3, list_input_a): <filter object at 0x00000243CBD83400>
print("filter(under_3, list_input_a):", list(output_b)) # filter(under_3, list_input_a): [1, 2]
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a): <map object at 0x00000243CBD83438>
# map(power, list_input_a): [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a): <filter object at 0x00000243CBD83400>
# filter(under_3, list_input_a): [1, 2]

# %% [markdown]
# 람다는 함수의 매개변수에 곧바로 넣을 수 있음

# %%
# 변수를 선언합니다.
list_input_a = [1, 2, 3, 4, 5]

# map() 함수를 사용합니다.
output_a = map(lambda x: x * x, list_input_a)
print("map(power, list_input_a):", output_a)
print("map(power, list_input_a):", list(output_a))

# filter() 함수를 사용합니다.
output_b = filter(lambda x: x < 3, list_input_a)
print("filter(under_3, list_input_a):", output_b)
print("filter(under_3, list_input_a):", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_input_a): <map object at 0x00000243CBD83160>
# map(power, list_input_a): [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_input_a): <filter object at 0x00000243CBD832E8>
# filter(under_3, list_input_a): [1, 2]

# %% [markdown]
# 파일처리
# : 파일의 종류는 텍스트 파일과 바이너리 파일로 나뉨

# %% [markdown]
# 파일 열고 닫기
# - open(파일경로, 모드) 함수를 사용
# - 모드의 종류
#     - 1) w : write 모드 (새로 쓰기 모드)
#     - 2) a : append 모드 (뒤에 이어서 쓰기모드)
#     - 3) r : read 모드 (읽기 모드)
# - close() 닫을 때 사용
# 파일객체.close()

# %%
# 파일을 엽니다.
file = open("basic.txt", "w")
# 파일에 텍스트를 씁니다.
file.write("Hello Python Programming...!")

# 파일을 닫습니다.
file.close()

# %% [markdown]
# with 키워드
# 파일의 읽고 닫기를 한번에 할 수 있음
# with open("문자열: 파일경로", "문자열 모드 : 모드") as 파일객체 :
#     코드

# %% [markdown]
# 텍스트 읽기
# read()
# 파일 객체.read()

# %%
# 파일을 엽니다.
with open("basic.txt", "r") as file:
    # 파일을 읽고 출력합니다.
    contents = file.read()
print(contents)

#  Hello Python Programming...!
# Out:
# Hello Python Programming...!

# %% [markdown]
# 텍스트 한줄씩 읽기
# 텍스트를 사용해 데이터를 구조적으로 표현할 수 있는 방법으로 csv, xml, json 등이 있음

# %%
# 랜덤한 숫자를 만들기 위해 가져옵니다.
import random
# 간단한 한글 리스트를 만듭니다.
hanguls = list("가나다라마바사아자차카타파하")
    
# 파일을 쓰기 모드로 엽니다.
with open("info.txt", "w") as file:
    for i in range(1000):
        # 랜덤한 값으로 변수를 생성합니다.
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40, 100)
        height = random.randrange(140, 200)
        # 텍스트를 씁니다.
        file.write("{}, {}, {}\n".format(name, weight, height))

# %%
with open("info.txt", "r") as file:
    for line in file:
        # 변수를 선언합니다.
        (name, weight, height) = line.strip().split(", ")

        # 데이터가 문제없는지 확인합니다: 문제가 있으면 지나감
        if (not name) or (not weight) or (not height):
            continue

        # 결과를 계산합니다.
        bmi = int(weight) / ((int(height) / 100) **2)
        result = ""
        if 25 <= bmi:
            result = "과체중"
        elif 18.5 <= bmi:
            result = "정상 체중"
        else:
            result = "저체중"

        # 출력합니다.
        print('\n'.join([
            "이름: {}",
            "몸무게: {}",
            "키: {}",
            "BMI: {}",
            "결과: {}"
        ]).format(name, weight, height, bmi, result))
        print()
# Out:
# 이름: 차라
# 몸무게: 92
# 키: 151
# BMI: 40.349107495285295
# 결과: 과체중
#
# 이름: 나타
# 몸무게: 96
# 키: 146
# BMI: 45.036592231187846
# 결과: 과체중
#
# 이름: 아자
# 몸무게: 88
# 키: 151
# BMI: 38.59479847375115
# 결과: 과체중
#
# 이름: 타나
# 몸무게: 61
# 키: 167
# BMI: 21.872422819032593
# 결과: 정상 체중
#
# 이름: 바라
# 몸무게: 88
# 키: 168
# BMI: 31.17913832199547
# 결과: 과체중
#
# 이름: 라파
# 몸무게: 94
# 키: 143
# BMI: 45.96801799599003
# 결과: 과체중
#
# 이름: 가가
# 몸무게: 93
# 키: 194
# BMI: 24.710383675204593
# 결과: 정상 체중
#
# 이름: 다가
# 몸무게: 63
# 키: 175
# BMI: 20.571428571428573
# 결과: 정상 체중
#
# 이름: 자마
# 몸무게: 92
# 키: 169
# BMI: 32.21175729141137
# 결과: 과체중
#
# 이름: 차자
# 몸무게: 85
# 키: 191
# BMI: 23.299799895836188
# 결과: 정상 체중
#
# 이름: 차라
# 몸무게: 81
# 키: 150
# BMI: 36.0
# 결과: 과체중
#
# 이름: 사바
# 몸무게: 76
# 키: 176
# BMI: 24.535123966942148
# 결과: 정상 체중
#
# 이름: 마타
# 몸무게: 51
# 키: 185
# BMI: 14.901387874360847
# 결과: 저체중
#
# 이름: 파차
# 몸무게: 63
# 키: 172
# BMI: 21.29529475392104
# 결과: 정상 체중
#
# 이름: 사파
# 몸무게: 68
# 키: 150
# BMI: 30.22222222222222
# 결과: 과체중
#
# 이름: 파차
# ...

# %% [markdown]
# 제너레이터
# 파이썬의 특수한 문법 구조
# 제너레이터는 이터레이터를 직접 만들때 사용하는 코드
# 함수 내부에서 yield 키워드를 사용하면 해당 함수는 제너레이터 함수가 되며, 일반 함수와는 달리함수를 호출해도 함수 내부의 코드가 실행되지 않음
# 제너레이터 객체는 next() 함수를 사용해 함수 내부의 코드를 실행

# %%
# 함수를 선언합니다.
def test():
    print("함수가 호출되었습니다.")
    yield test

# 함수를 호출합니다.
print("A 지점 통과") # A 지점 통과
test()

print("B 지점 통과") # B 지점 통과
test()
print(test()) # <generator object test at 0x00000243CBD913B8>
# Out:
# A 지점 통과
# B 지점 통과
# <generator object test at 0x00000243CBD913B8>

# %% [markdown]
# 제너레이터 객체는 함수의 코드를 조금씩 실핼할 때 사용합니다. 이는 메모리의 효율성을 위해서이며, reverser() 함수가 모두 제너레이터 객체를 생성할 때 사용하는 함수
# next() 함수를 호출한 이후 yield 키워드를 만나지 못하고 함수가 끝나면 StopIteration 예외 발생

# %%
# 함수를 선언합니다.  
def test():  
    print("A 지점 통과")  
    yield 1  
    print("B 지점 통과")  
    yield 2  
    print("C 지점 통과")  
	
# 함수를 호출합니다.  
output = test()  
	
# next() 함수를 호출합니다.  
print("D 지점 통과") # D 지점 통과  
a = next(output)  
print(a) # A 지점 통과    
	      # 1
print("E 지점 통과") # E 지점 통과  
b = next(output)  
print(b) # B 지점 통과  
         # 2
print("F 지점 통과") # F 지점 통과 
c = next(output)   
print(c) # C 지점 통과  

# 한번 더 실행하기  
next(output)  # StopIteration 에러 발생
# Out:
# D 지점 통과
# A 지점 통과
# 1
# E 지점 통과
# B 지점 통과
# 2
# F 지점 통과
# C 지점 통과
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-45-35236a47cf83> in <module>
#      20
#      21 print("F 지점 통과")
# ---> 22 c = next(output)
#      23 print(c)
#      24
#
# StopIteration:
