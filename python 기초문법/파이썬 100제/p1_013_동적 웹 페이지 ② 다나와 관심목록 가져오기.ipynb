# %%
from selenium import webdriver

driver = webdriver.Chrome('./chromedriver.exe')
driver.implicitly_wait(3)
driver.get('https://www.danawa.com/')

# 다나와 메인화면의 로그인 버튼을 누르는 작업을 실행
login = driver.find_element_by_css_selector('li.my_page_service > a')
login.click()
driver.implicitly_wait(3)

# 아이디/ 비밀번호를 입력하고 로그인하기 버튼을 누르는 작업 실행
my_id = ' '
my_pw = ' '

driver.find_element_by_id('danawa-member-login-input-id').send_keys(my_id)
driver.implicitly_wait(2)
driver.find_element_by_name('password').send_keys(my_pw)
driver.implicitly_wait(2)
driver.find_element_by_css_selector('button.btn_login').click()
driver.implicitly_wait(2)

# 관심상품 목록 HTML 페이지 가졍기
wishlist = driver.find_element_by_css_selector('li.interest_goods_service > a').click()
html_src = driver.page_source
driver.close()
print(html_src[:500])
print('\n')

# 관심상품 목록 HTML 페이지를 BeautifulSoup으로 파싱하기
from bs4 import BeautifulSoup
import re

soup = BeautifulSoup(html_src, 'html.parser')

wish_table = soup.select('table[class="tbl wish_tbl"]')[0]
wish_items = wish_table.select('tbody tr')

for item in wish_items:
    title = item.find('div', {'class':'tit'}).text
    price = item.find('span', {'class':'price'}).text
    link = item.find('a', href=re.compile('prod.danawa.com/info/')).get('href')
    print(title)
    print(price)
    print(link)
    print('\n')
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko"><head>
# <title>관심상품 : 다나와 마이페이지</title>
# <!-- <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/> -->
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="Title" content="관심상품 : 다나와 마이페이지"><meta name="Description" content="다나와는 온라인 전제품에 대한 가격비교 사이트 입니다. 안전구매시스템(전자보증,Escrow)을 갖춘 쇼핑몰의 최저 가격 정보를 보여드리며, 다양한 각도의 상품 사진, 상세 설명, 소비자 의견 등을 한곳에서 볼
#
#
# 동서가구 아랜 가죽 전동 리클라이너 1인용
# 245,560원
# http://prod.danawa.com/info/?pcode=7001230
#
#
# 아이가구 어반레스트 러블렌 가죽 전동 리클라이너 1인용
# 283,280원
# http://prod.danawa.com/info/?pcode=5689414
#
#
# 상도가구 이지체어 블렛 가죽 전동 리클라이너 1인용
# 206,470원
# http://prod.danawa.com/info/?pcode=5483111
#
#
# 프렌즈에프앤비 클렙튼 퍼스트클래스 BB0002 가죽 전동 리클라이너 1인용
# 278,180원
# http://prod.danawa.com/info/?pcode=9714495
#
#
# 프렌즈에프앤비 클렙튼 퍼스트클래스 0049 가죽 전동 리클라이너 1인용
# 240,810원
# http://prod.danawa.com/info/?pcode=5744785
#
#
# 이노센트플러스 리브 헤븐 가죽 전동 리클라이너 1인용
# 262,580원
# http://prod.danawa.com/info/?pcode=9738975
#
#
# 상도가구 이지체어 아폴론 가죽 전동 리클라이너 1인용
# 259,660원
# http://prod.danawa.com/info/?pcode=3554947
#
#
# 동서가구 코니 가죽 전동 리클라이너 1인용
# 253,360원
# http://prod.danawa.com/info/?pcode=7332346
#
#
# 채우리 푹쉼 시크릿 가죽 전동 리클라이너 1인용
# 265,320원
# http://prod.danawa.com/info/?pcode=5610767
#
#
# 프렌즈에프앤비 클렙튼 퍼스트클래스 0001 가죽 전동 리클라이너 1인용
# 278,260원
# http://prod.danawa.com/info/?pcode=5750154
#
#
# 썬퍼니처 7108 가죽 전동 리클라이너 1인용
# 263,120원
# http://prod.danawa.com/info/?pcode=10497222
#
#
# 베이직팩토리 스코나 8032 엘리카 가죽 전동 리클라이너 1인용
# 252,890원
# http://prod.danawa.com/info/?pcode=6173391
#
#
# 상도가구 이지체어 모나코 8650 가죽 전동 리클라이너 1인용
# 247,570원
# http://prod.danawa.com/info/?pcode=1769790
#
#
# 수오 모에르 에어레더 가죽 전동 리클라이너 1인용
# 242,730원
# http://prod.danawa.com/info/?pcode=10607568
#
#
# 라로퍼니처 리오 가죽 전동 리클라이너 1인용
# 223,000원
# http://prod.danawa.com/info/?pcode=10532952
#
#
# 프렌즈에프앤비 클렙튼 퍼스트클래스 0005 가죽 전동 리클라이너 1인용
# 288,700원
# http://prod.danawa.com/info/?pcode=5662281
#
#
# 에보니아 럭스 천연가죽 전동 리클라이너 1인용
# 227,300원
# http://prod.danawa.com/info/?pcode=6978823
#
#
# 에넥스 ENNEE 루작 에어레더 가죽 전동 리클라이너 1인용
# 295,600원
# http://prod.danawa.com/info/?pcode=10575414
#
#
# 프렌즈에프앤비 클렙튼 퍼스트클래스 0032 가죽 전동 리클라이너 1인용
# 208,870원
# http://prod.danawa.com/info/?pcode=5691292
#
#
# 라로퍼니처 체이스 천연가죽 전동 리클라이너 1인용
# 195,000원
# http://prod.danawa.com/info/?pcode=9384300
