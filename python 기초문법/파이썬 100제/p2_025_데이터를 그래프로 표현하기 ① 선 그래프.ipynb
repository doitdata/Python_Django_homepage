# %%
import pandas as pd

# 예제 17의 CSV 파일을 다시 활용, 데이터 프레임으로 변환
df = pd.read_csv('./data/bok_statistics_CD.csv', header=None)
print(df.head())
print('\n')

df.columns = ['year', 'CD_rate', 'change'] # 열 이름 변경
df.set_index('year', inplace = True) # year 열을 행 인덱스로 설정
print(df.head())
df.to_csv('./data/bok_statistics_CD_2.csv')
print('\n')

# 선 그래프 그리기
df.plot()

df['CD_rate'].plot()
df['change'].plot()
# Out:
#       0     1     2
# 0  2013  2.72 -0.58
# 1  2014  2.49 -0.23
# 2  2015  1.76 -0.73
# 3  2016  1.49 -0.27
# 4  2017  1.44 -0.05
#
#
#       CD_rate  change
# year
# 2013     2.72   -0.58
# 2014     2.49   -0.23
# 2015     1.76   -0.73
# 2016     1.49   -0.27
# 2017     1.44   -0.05
